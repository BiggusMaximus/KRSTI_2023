# %%
import pandas as pd

df = pd.read_excel("data.xlsx")
df.to_csv("data.csv")

# %%
df
# Out:
#     stabil  melambai_kiri  salam  melambai_kanan  vampire  gerakn 12 detik  \
# 0       75              0    120             110    180.0            225.0
# 1      115             90    140             150    180.0            225.0
# 2      180            180    180             180    200.0            225.0
# 3        0              0      0               0      0.0             90.0
# 4      115            150    140              80      NaN              NaN
# 5       70             10      0             150      NaN              NaN
# 6       25             25     25              25      NaN              NaN
# 7      180            180    180             180      NaN              NaN
# 8      110            110    110             110    180.0              NaN
# 9      110            110    110             110      NaN              NaN
# 10      30             30     30              30      NaN              NaN
# 11      80             80     80              80      NaN              NaN
# 12      90             90     90              90    180.0             90.0
# 13     120            120    120             120    160.0            100.0
# 14     115            115    115             115    210.0              NaN
# 15     120            120    120             120      0.0              0.0
#
#     servo pinggang 0 derajat  gerakan_45 derajat kanan  gerakan_ 0 derajat  \
# 0                      180.0                       NaN                 NaN
# 1                      225.0                       NaN                 NaN
# 2                      210.0                       NaN                 NaN
# 3                        0.0                       NaN                 NaN
# 4                        NaN                       NaN                 NaN
# 5                        NaN                       NaN                 NaN
# 6                        NaN                       NaN                 NaN
# 7                        NaN                       NaN                 NaN
# 8                        NaN                     180.0               180.0
# 9                        NaN                       NaN                 NaN
# 10                       NaN                       NaN                 NaN
# 11                       NaN                       NaN                 NaN
# 12                     180.0                       NaN                 NaN
# 13                      90.0                       NaN                 NaN
# 14                     260.0                       NaN                 NaN
# 15                      90.0                       NaN                 NaN
#
#     gerakan pinggang kiri  gerakan pinggang tengah pertama  \
# 0                   180.0                            180.0
# 1                   250.0                            180.0
# 2                    45.0                            270.0
# 3                    90.0                              0.0
# 4                     NaN                              NaN
# 5                     NaN                              NaN
# 6                     NaN                              NaN
# 7                     NaN                              NaN
# 8                   180.0                            180.0
# 9                     NaN                              NaN
# 10                    NaN                              NaN
# 11                    NaN                              NaN
# 12                  180.0                            180.0
# 13                   45.0                            160.0
# 14                  210.0                            250.0
# 15                    0.0                              0.0
#
#     gerakan pinggang tengah kedua  gerakan pinggang kanan pertama  \
# 0                           180.0                           180.0
# 1                           300.0                           240.0
# 2                           270.0                           200.0
# 3                             0.0                            90.0
# 4                             NaN                             NaN
# 5                             NaN                             NaN
# 6                             NaN                             NaN
# 7                             NaN                             NaN
# 8                             NaN                            90.0
# 9                             NaN                             NaN
# 10                            NaN                             NaN
# 11                            NaN                             NaN
# 12                          180.0                           180.0
# 13                          280.0                           100.0
# 14                          250.0                           210.0
# 15                            0.0                            90.0
#
#     gerakn pinggang kanan kedua
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           0.0
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          0.0

# %%
slave_servo_index   = [8, 14, 13, 12, 0, 1, 2, 3, 0]
# Protokol index master
master_servo_index   = [i for i in range(0,9)]
# Konstanta kalibrasi 
k = [-115, -95, -20, -360, -115, -110, -125, 180, -115]
# Index master
stabil_order        = [0, 5, 1, 4, 2, 3, 7, 6, 9, 8, 10, 11, 12, 13, 14, 15]
salam_order         = [2, 3, 0, 5, 1, 4]

# Index Slave
vampire_order       = [0, 1, 2, 3, 8, 12, 13, 14]

# %%
'''

[0, 1, 2, 3, 8, 12, 13, 14]
[4, 5, 6, 7, 0, 3, 2, 1]

'''

convert_index(vampire_order)
# Out:
# [4, 5, 6, 7, 0, 3, 2, 1]
